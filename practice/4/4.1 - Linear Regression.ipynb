# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([3.17897678, 1.27926363, 2.31596839, 3.17188336, 4.27433872,
#        2.1099384 , 1.84713176, 3.16728672, 4.44969091, 3.36696383,
#        4.77833506, 4.00403936, 3.50225682, 2.01372737, 4.02819366,
#        2.21174131, 2.93353589, 0.25936006, 3.87396668, 0.25327372,
#        3.58392678, 3.43529278, 3.44951163, 3.76590416, 3.56162296,
#        4.27400369, 2.26531561, 1.32440521, 3.98093054, 3.23563041,
#        1.94049049, 1.61285373, 4.0407247 , 4.44437371, 3.71704445,
#        3.12248247, 4.86411854, 4.40000307, 2.26713921, 3.63661415,
#        1.91314567, 4.44602441, 3.68171366, 0.41397498, 4.82915214,
#        4.69881162, 1.55604083, 3.93543853, 2.59129528, 2.94166689,
#        0.81002416, 2.50113563, 2.18360757, 2.12563165, 0.60418722,
#        4.30049591, 3.53168907, 1.19179103, 3.17006965, 3.9432643 ,
#        4.70254559, 4.10407591, 2.16994964, 2.46491975, 0.59206234,
#        4.34787303, 3.17415408, 4.63716841, 2.30083135, 1.37993737,
#        4.62544965, 4.06270071, 3.28617991, 0.13305114, 4.32047446,
#        3.91037053, 4.43455786, 4.12853757, 1.95355338, 3.51801503,
#        0.47717464, 2.80292321, 0.78852346, 0.78530263, 1.27664329,
#        1.8006274 , 2.00212262, 4.70451879, 4.17661547, 3.93741376,
#        1.11613154, 3.26992874, 0.42323633, 2.53237689, 2.98807994,
#        1.34930346, 1.23875804, 4.90665716, 2.87202144, 0.54380267])

# %%
X # array where each row is an array to
# Out:
# array([[3.17897678],
#        [1.27926363],
#        [2.31596839],
#        [3.17188336],
#        [4.27433872],
#        [2.1099384 ],
#        [1.84713176],
#        [3.16728672],
#        [4.44969091],
#        [3.36696383],
#        [4.77833506],
#        [4.00403936],
#        [3.50225682],
#        [2.01372737],
#        [4.02819366],
#        [2.21174131],
#        [2.93353589],
#        [0.25936006],
#        [3.87396668],
#        [0.25327372],
#        [3.58392678],
#        [3.43529278],
#        [3.44951163],
#        [3.76590416],
#        [3.56162296],
#        [4.27400369],
#        [2.26531561],
#        [1.32440521],
#        [3.98093054],
#        [3.23563041],
#        [1.94049049],
#        [1.61285373],
#        [4.0407247 ],
#        [4.44437371],
#        [3.71704445],
#        [3.12248247],
#        [4.86411854],
#        [4.40000307],
#        [2.26713921],
#        [3.63661415],
#        [1.91314567],
#        [4.44602441],
#        [3.68171366],
#        [0.41397498],
#        [4.82915214],
#        [4.69881162],
#        [1.55604083],
#        [3.93543853],
#        [2.59129528],
#        [2.94166689],
#        [0.81002416],
#        [2.50113563],
#        [2.18360757],
#        [2.12563165],
#        [0.60418722],
#        [4.30049591],
#        [3.53168907],
#        [1.19179103],
#        [3.17006965],
#        [3.9432643 ],
#        [4.70254559],
#        [4.10407591],
#        [2.16994964],
#        [2.46491975],
#        [0.59206234],
#        [4.34787303],
#        [3.17415408],
#        [4.63716841],
#        [2.30083135],
#        [1.37993737],
#        [4.62544965],
#        [4.06270071],
#        [3.28617991],
#        [0.13305114],
#        [4.32047446],
#        [3.91037053],
#        [4.43455786],
#        [4.12853757],
#        [1.95355338],
#        [3.51801503],
#        [0.47717464],
#        [2.80292321],
#        [0.78852346],
#        [0.78530263],
#        [1.27664329],
#        [1.8006274 ],
#        [2.00212262],
#        [4.70451879],
#        [4.17661547],
#        [3.93741376],
#        [1.11613154],
#        [3.26992874],
#        [0.42323633],
#        [2.53237689],
#        [2.98807994],
#        [1.34930346],
#        [1.23875804],
#        [4.90665716],
#        [2.87202144],
#        [0.54380267]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(1.0176374288318086)

# %%
b_found
# Out:
# np.float64(2.911007754328772)
